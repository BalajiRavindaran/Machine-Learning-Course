# %% [markdown]
# data input and output

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# .csv file

# %%
df = pd.read_csv('/content/drive/My Drive/ML:March2020/Assignments/example')
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %% [markdown]
# .csv (output)

# %%
df.to_csv('example',index=False)

# %% [markdown]
# .excel file xlsx

# %%
 df= pd.read_excel('/content/drive/My Drive/ML:March2020/Assignments/Excel.xlsx',sheet_name='Sheet1')
 df
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %% [markdown]
# .excel (output)

# %%
df.to_excel('Excel.xlsx',sheet_name='Sheet1')

# %% [markdown]
# .html

# %%
df = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')
df
# Out:
# [                             Bank Name  ...       Closing Date
#  0                   Ericson State Bank  ...  February 14, 2020
#  1     City National Bank of New Jersey  ...   November 1, 2019
#  2                        Resolute Bank  ...   October 25, 2019
#  3                Louisa Community Bank  ...   October 25, 2019
#  4                 The Enloe State Bank  ...       May 31, 2019
#  ..                                 ...  ...                ...
#  555                 Superior Bank, FSB  ...      July 27, 2001
#  556                Malta National Bank  ...        May 3, 2001
#  557    First Alliance Bank & Trust Co.  ...   February 2, 2001
#  558  National State Bank of Metropolis  ...  December 14, 2000
#  559                   Bank of Honolulu  ...   October 13, 2000
#
#  [560 rows x 6 columns]]

# %% [markdown]
# .sql

# %%
from sqlalchemy import create_engine
import pandas_datareader.data as web
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/drive/My Drive/ML:March2020/Assignments/example')
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
engine = create_engine('sqlite:///:memory:')
print (engine)
# Out:
# Engine(sqlite:///:memory:)

# %%
df.to_sql('data', engine)

# %%
sql_df = pd.read_sql('data',con=engine)

# %%
sql_df
# Out:
#    index   a   b   c   d
# 0      0   0   1   2   3
# 1      1   4   5   6   7
# 2      2   8   9  10  11
# 3      3  12  13  14  15

# %% [markdown]
# data frames

# %%
from numpy.random import randn
np.random.seed(500)

# %%
df=pd.DataFrame(randn(10,10),index='z x c v b n m a s d'.split(),columns='f g h j k l q w e r '.split())
df
# Out:
#           f         g         h  ...         w         e         r
# z -0.377364  0.166759  0.682802  ... -0.036373 -1.217749 -1.428905
# x -0.170528  1.160940 -1.061140  ... -0.307186 -0.080870  0.834319
# c  1.885460  0.440898  0.439874  ...  1.002275 -0.047000  1.153260
# v  0.019985 -1.579930 -0.197842  ...  1.663777  0.603633  0.231452
# b  0.368404 -0.497894  1.567452  ... -0.854184  1.676691 -0.461345
# n  0.253380  0.760322  0.283970  ...  0.112940  0.636776 -0.657319
# m  0.569960  0.949293  1.057859  ...  0.963320  0.036998  1.260493
# a -0.776506  0.764746  0.394545  ...  1.099562 -1.051470  0.757635
# s  1.345002 -0.816321  0.992483  ... -1.002387 -1.810059 -0.187311
# d  1.004061 -0.046574 -1.019231  ... -0.307212 -0.495637 -0.793462
#
# [10 rows x 10 columns]

# %% [markdown]
# selection and indexing

# %%
df["q"]
# Out:
# z   -2.089066
# x   -1.736265
# c    1.937107
# v    1.049545
# b   -0.960112
# n    0.021039
# m    0.895592
# a    0.118941
# s    0.706138
# d   -0.992287
# Name: q, dtype: float64

# %%
df[['g','j']]
# Out:
#           g         j
# z  0.166759  1.921379
# x  1.160940 -1.408500
# c  0.440898  1.070767
# v -1.579930 -0.220196
# b -0.497894  0.469145
# n  0.760322 -0.469825
# m  0.949293  0.603935
# a  0.764746  0.105635
# s -0.816321  0.492420
# d -0.046574  0.428562

# %%
df.j
# Out:
# z    1.921379
# x   -1.408500
# c    1.070767
# v   -0.220196
# b    0.469145
# n   -0.469825
# m    0.603935
# a    0.105635
# s    0.492420
# d    0.428562
# Name: j, dtype: float64

# %%
type(df['j'])
# Out:
# pandas.core.series.Series

# %%
df['t']=df['k']+df['l']

# %%
df
# Out:
#           f         g         h  ...         e         r         t
# z -0.377364  0.166759  0.682802  ... -1.217749 -1.428905 -0.956916
# x -0.170528  1.160940 -1.061140  ... -0.080870  0.834319  0.739925
# c  1.885460  0.440898  0.439874  ... -0.047000  1.153260  0.537724
# v  0.019985 -1.579930 -0.197842  ...  0.603633  0.231452 -0.679214
# b  0.368404 -0.497894  1.567452  ...  1.676691 -0.461345  0.214179
# n  0.253380  0.760322  0.283970  ...  0.636776 -0.657319  0.466299
# m  0.569960  0.949293  1.057859  ...  0.036998  1.260493  0.063923
# a -0.776506  0.764746  0.394545  ... -1.051470  0.757635  0.077361
# s  1.345002 -0.816321  0.992483  ... -1.810059 -0.187311  2.075089
# d  1.004061 -0.046574 -1.019231  ... -0.495637 -0.793462 -0.165432
#
# [10 rows x 11 columns]

# %%
df.drop('t',axis=1)
# Out:
#           f         g         h  ...         w         e         r
# z -0.377364  0.166759  0.682802  ... -0.036373 -1.217749 -1.428905
# x -0.170528  1.160940 -1.061140  ... -0.307186 -0.080870  0.834319
# c  1.885460  0.440898  0.439874  ...  1.002275 -0.047000  1.153260
# v  0.019985 -1.579930 -0.197842  ...  1.663777  0.603633  0.231452
# b  0.368404 -0.497894  1.567452  ... -0.854184  1.676691 -0.461345
# n  0.253380  0.760322  0.283970  ...  0.112940  0.636776 -0.657319
# m  0.569960  0.949293  1.057859  ...  0.963320  0.036998  1.260493
# a -0.776506  0.764746  0.394545  ...  1.099562 -1.051470  0.757635
# s  1.345002 -0.816321  0.992483  ... -1.002387 -1.810059 -0.187311
# d  1.004061 -0.046574 -1.019231  ... -0.307212 -0.495637 -0.793462
#
# [10 rows x 10 columns]

# %%
df.drop('d',axis=0)
# Out:
#           f         g         h  ...         e         r         t
# z -0.377364  0.166759  0.682802  ... -1.217749 -1.428905 -0.956916
# x -0.170528  1.160940 -1.061140  ... -0.080870  0.834319  0.739925
# c  1.885460  0.440898  0.439874  ... -0.047000  1.153260  0.537724
# v  0.019985 -1.579930 -0.197842  ...  0.603633  0.231452 -0.679214
# b  0.368404 -0.497894  1.567452  ...  1.676691 -0.461345  0.214179
# n  0.253380  0.760322  0.283970  ...  0.636776 -0.657319  0.466299
# m  0.569960  0.949293  1.057859  ...  0.036998  1.260493  0.063923
# a -0.776506  0.764746  0.394545  ... -1.051470  0.757635  0.077361
# s  1.345002 -0.816321  0.992483  ... -1.810059 -0.187311  2.075089
#
# [9 rows x 11 columns]

# %%
df
# Out:
#           f         g         h  ...         e         r         t
# z -0.377364  0.166759  0.682802  ... -1.217749 -1.428905 -0.956916
# x -0.170528  1.160940 -1.061140  ... -0.080870  0.834319  0.739925
# c  1.885460  0.440898  0.439874  ... -0.047000  1.153260  0.537724
# v  0.019985 -1.579930 -0.197842  ...  0.603633  0.231452 -0.679214
# b  0.368404 -0.497894  1.567452  ...  1.676691 -0.461345  0.214179
# n  0.253380  0.760322  0.283970  ...  0.636776 -0.657319  0.466299
# m  0.569960  0.949293  1.057859  ...  0.036998  1.260493  0.063923
# a -0.776506  0.764746  0.394545  ... -1.051470  0.757635  0.077361
# s  1.345002 -0.816321  0.992483  ... -1.810059 -0.187311  2.075089
# d  1.004061 -0.046574 -1.019231  ... -0.495637 -0.793462 -0.165432
#
# [10 rows x 11 columns]

# %%
df.drop('t',axis=1,inplace=True)

# %%
df
# Out:
#           f         g         h  ...         w         e         r
# z -0.377364  0.166759  0.682802  ... -0.036373 -1.217749 -1.428905
# x -0.170528  1.160940 -1.061140  ... -0.307186 -0.080870  0.834319
# c  1.885460  0.440898  0.439874  ...  1.002275 -0.047000  1.153260
# v  0.019985 -1.579930 -0.197842  ...  1.663777  0.603633  0.231452
# b  0.368404 -0.497894  1.567452  ... -0.854184  1.676691 -0.461345
# n  0.253380  0.760322  0.283970  ...  0.112940  0.636776 -0.657319
# m  0.569960  0.949293  1.057859  ...  0.963320  0.036998  1.260493
# a -0.776506  0.764746  0.394545  ...  1.099562 -1.051470  0.757635
# s  1.345002 -0.816321  0.992483  ... -1.002387 -1.810059 -0.187311
# d  1.004061 -0.046574 -1.019231  ... -0.307212 -0.495637 -0.793462
#
# [10 rows x 10 columns]

# %%
df.loc['b']
# Out:
# f    0.368404
# g   -0.497894
# h    1.567452
# j    0.469145
# k    0.545377
# l   -0.331197
# q   -0.960112
# w   -0.854184
# e    1.676691
# r   -0.461345
# Name: b, dtype: float64

# %%
df.iloc[3] #v
# Out:
# f    0.019985
# g   -1.579930
# h   -0.197842
# j   -0.220196
# k   -0.267084
# l   -0.412130
# q    1.049545
# w    1.663777
# e    0.603633
# r    0.231452
# Name: v, dtype: float64

# %%
df.loc['x','j']
# Out:
# -1.408500171343385

# %%
df.loc[['m','b'],['k','l']]
# Out:
#           k         l
# m  0.008752  0.055171
# b  0.545377 -0.331197

# %% [markdown]
# conditional selection

# %%
df
# Out:
#           f         g         h  ...         w         e         r
# z -0.377364  0.166759  0.682802  ... -0.036373 -1.217749 -1.428905
# x -0.170528  1.160940 -1.061140  ... -0.307186 -0.080870  0.834319
# c  1.885460  0.440898  0.439874  ...  1.002275 -0.047000  1.153260
# v  0.019985 -1.579930 -0.197842  ...  1.663777  0.603633  0.231452
# b  0.368404 -0.497894  1.567452  ... -0.854184  1.676691 -0.461345
# n  0.253380  0.760322  0.283970  ...  0.112940  0.636776 -0.657319
# m  0.569960  0.949293  1.057859  ...  0.963320  0.036998  1.260493
# a -0.776506  0.764746  0.394545  ...  1.099562 -1.051470  0.757635
# s  1.345002 -0.816321  0.992483  ... -1.002387 -1.810059 -0.187311
# d  1.004061 -0.046574 -1.019231  ... -0.307212 -0.495637 -0.793462
#
# [10 rows x 10 columns]

# %%
df>0
# Out:
#        f      g      h      j      k      l      q      w      e      r
# z  False   True   True   True  False  False  False  False  False  False
# x  False   True  False  False   True  False  False  False  False   True
# c   True   True   True   True   True   True   True   True  False   True
# v   True  False  False  False  False  False   True   True   True   True
# b   True  False   True   True   True  False  False  False   True  False
# n   True   True   True  False  False   True   True   True   True  False
# m   True   True   True   True   True   True   True   True   True   True
# a  False   True   True   True   True  False   True   True  False   True
# s   True  False   True   True   True   True   True  False  False  False
# d   True  False  False   True  False   True  False  False  False  False

# %%
df[df>0]
# Out:
#           f         g         h  ...         w         e         r
# z       NaN  0.166759  0.682802  ...       NaN       NaN       NaN
# x       NaN  1.160940       NaN  ...       NaN       NaN  0.834319
# c  1.885460  0.440898  0.439874  ...  1.002275       NaN  1.153260
# v  0.019985       NaN       NaN  ...  1.663777  0.603633  0.231452
# b  0.368404       NaN  1.567452  ...       NaN  1.676691       NaN
# n  0.253380  0.760322  0.283970  ...  0.112940  0.636776       NaN
# m  0.569960  0.949293  1.057859  ...  0.963320  0.036998  1.260493
# a       NaN  0.764746  0.394545  ...  1.099562       NaN  0.757635
# s  1.345002       NaN  0.992483  ...       NaN       NaN       NaN
# d  1.004061       NaN       NaN  ...       NaN       NaN       NaN
#
# [10 rows x 10 columns]

# %%
df[df['j']>0] # prints index which does have j value > 0
# Out:
#           f         g         h  ...         w         e         r
# z -0.377364  0.166759  0.682802  ... -0.036373 -1.217749 -1.428905
# c  1.885460  0.440898  0.439874  ...  1.002275 -0.047000  1.153260
# b  0.368404 -0.497894  1.567452  ... -0.854184  1.676691 -0.461345
# m  0.569960  0.949293  1.057859  ...  0.963320  0.036998  1.260493
# a -0.776506  0.764746  0.394545  ...  1.099562 -1.051470  0.757635
# s  1.345002 -0.816321  0.992483  ... -1.002387 -1.810059 -0.187311
# d  1.004061 -0.046574 -1.019231  ... -0.307212 -0.495637 -0.793462
#
# [7 rows x 10 columns]

# %%
df[df['j']>0]['l'] # prints index of l in which j have value>0
# Out:
# z   -0.759879
# c    0.133472
# b   -0.331197
# m    0.055171
# a   -0.090767
# s    1.138867
# d    0.093073
# Name: l, dtype: float64

# %%
df[df['l']>0][['k','q']]
# Out:
#           k         q
# c  0.404252  1.937107
# n -0.761015  0.021039
# m  0.008752  0.895592
# s  0.936222  0.706138
# d -0.258505 -0.992287

# %%
df[(df['q']>0)& (df['h'] > 0)]
# Out:
#           f         g         h  ...         w         e         r
# c  1.885460  0.440898  0.439874  ...  1.002275 -0.047000  1.153260
# n  0.253380  0.760322  0.283970  ...  0.112940  0.636776 -0.657319
# m  0.569960  0.949293  1.057859  ...  0.963320  0.036998  1.260493
# a -0.776506  0.764746  0.394545  ...  1.099562 -1.051470  0.757635
# s  1.345002 -0.816321  0.992483  ... -1.002387 -1.810059 -0.187311
#
# [5 rows x 10 columns]

# %%
df
# Out:
#           f         g         h  ...         w         e         r
# z -0.377364  0.166759  0.682802  ... -0.036373 -1.217749 -1.428905
# x -0.170528  1.160940 -1.061140  ... -0.307186 -0.080870  0.834319
# c  1.885460  0.440898  0.439874  ...  1.002275 -0.047000  1.153260
# v  0.019985 -1.579930 -0.197842  ...  1.663777  0.603633  0.231452
# b  0.368404 -0.497894  1.567452  ... -0.854184  1.676691 -0.461345
# n  0.253380  0.760322  0.283970  ...  0.112940  0.636776 -0.657319
# m  0.569960  0.949293  1.057859  ...  0.963320  0.036998  1.260493
# a -0.776506  0.764746  0.394545  ...  1.099562 -1.051470  0.757635
# s  1.345002 -0.816321  0.992483  ... -1.002387 -1.810059 -0.187311
# d  1.004061 -0.046574 -1.019231  ... -0.307212 -0.495637 -0.793462
#
# [10 rows x 10 columns]

# %%
df.reset_index()
# Out:
#   index         f         g         h  ...         q         w         e         r
# 0     z -0.377364  0.166759  0.682802  ... -2.089066 -0.036373 -1.217749 -1.428905
# 1     x -0.170528  1.160940 -1.061140  ... -1.736265 -0.307186 -0.080870  0.834319
# 2     c  1.885460  0.440898  0.439874  ...  1.937107  1.002275 -0.047000  1.153260
# 3     v  0.019985 -1.579930 -0.197842  ...  1.049545  1.663777  0.603633  0.231452
# 4     b  0.368404 -0.497894  1.567452  ... -0.960112 -0.854184  1.676691 -0.461345
# 5     n  0.253380  0.760322  0.283970  ...  0.021039  0.112940  0.636776 -0.657319
# 6     m  0.569960  0.949293  1.057859  ...  0.895592  0.963320  0.036998  1.260493
# 7     a -0.776506  0.764746  0.394545  ...  0.118941  1.099562 -1.051470  0.757635
# 8     s  1.345002 -0.816321  0.992483  ...  0.706138 -1.002387 -1.810059 -0.187311
# 9     d  1.004061 -0.046574 -1.019231  ... -0.992287 -0.307212 -0.495637 -0.793462
#
# [10 rows x 11 columns]

# %%
x='vu bh ny ni no nt my np al vw'.split()
df['states']=x
df
# Out:
#           f         g         h         j  ...         w         e         r  states
# z -0.377364  0.166759  0.682802  1.921379  ... -0.036373 -1.217749 -1.428905      vu
# x -0.170528  1.160940 -1.061140 -1.408500  ... -0.307186 -0.080870  0.834319      bh
# c  1.885460  0.440898  0.439874  1.070767  ...  1.002275 -0.047000  1.153260      ny
# v  0.019985 -1.579930 -0.197842 -0.220196  ...  1.663777  0.603633  0.231452      ni
# b  0.368404 -0.497894  1.567452  0.469145  ... -0.854184  1.676691 -0.461345      no
# n  0.253380  0.760322  0.283970 -0.469825  ...  0.112940  0.636776 -0.657319      nt
# m  0.569960  0.949293  1.057859  0.603935  ...  0.963320  0.036998  1.260493      my
# a -0.776506  0.764746  0.394545  0.105635  ...  1.099562 -1.051470  0.757635      np
# s  1.345002 -0.816321  0.992483  0.492420  ... -1.002387 -1.810059 -0.187311      al
# d  1.004061 -0.046574 -1.019231  0.428562  ... -0.307212 -0.495637 -0.793462      vw
#
# [10 rows x 11 columns]

# %%
df.set_index('states')
# Out:
#                f         g         h  ...         w         e         r
# states                                ...
# vu     -0.377364  0.166759  0.682802  ... -0.036373 -1.217749 -1.428905
# bh     -0.170528  1.160940 -1.061140  ... -0.307186 -0.080870  0.834319
# ny      1.885460  0.440898  0.439874  ...  1.002275 -0.047000  1.153260
# ni      0.019985 -1.579930 -0.197842  ...  1.663777  0.603633  0.231452
# no      0.368404 -0.497894  1.567452  ... -0.854184  1.676691 -0.461345
# nt      0.253380  0.760322  0.283970  ...  0.112940  0.636776 -0.657319
# my      0.569960  0.949293  1.057859  ...  0.963320  0.036998  1.260493
# np     -0.776506  0.764746  0.394545  ...  1.099562 -1.051470  0.757635
# al      1.345002 -0.816321  0.992483  ... -1.002387 -1.810059 -0.187311
# vw      1.004061 -0.046574 -1.019231  ... -0.307212 -0.495637 -0.793462
#
# [10 rows x 10 columns]

# %%
df
# Out:
#           f         g         h         j  ...         w         e         r  states
# z -0.377364  0.166759  0.682802  1.921379  ... -0.036373 -1.217749 -1.428905      vu
# x -0.170528  1.160940 -1.061140 -1.408500  ... -0.307186 -0.080870  0.834319      bh
# c  1.885460  0.440898  0.439874  1.070767  ...  1.002275 -0.047000  1.153260      ny
# v  0.019985 -1.579930 -0.197842 -0.220196  ...  1.663777  0.603633  0.231452      ni
# b  0.368404 -0.497894  1.567452  0.469145  ... -0.854184  1.676691 -0.461345      no
# n  0.253380  0.760322  0.283970 -0.469825  ...  0.112940  0.636776 -0.657319      nt
# m  0.569960  0.949293  1.057859  0.603935  ...  0.963320  0.036998  1.260493      my
# a -0.776506  0.764746  0.394545  0.105635  ...  1.099562 -1.051470  0.757635      np
# s  1.345002 -0.816321  0.992483  0.492420  ... -1.002387 -1.810059 -0.187311      al
# d  1.004061 -0.046574 -1.019231  0.428562  ... -0.307212 -0.495637 -0.793462      vw
#
# [10 rows x 11 columns]

# %%
df.set_index('states',inplace=True)

# %%
df
# Out:
#                f         g         h  ...         w         e         r
# states                                ...
# vu     -0.377364  0.166759  0.682802  ... -0.036373 -1.217749 -1.428905
# bh     -0.170528  1.160940 -1.061140  ... -0.307186 -0.080870  0.834319
# ny      1.885460  0.440898  0.439874  ...  1.002275 -0.047000  1.153260
# ni      0.019985 -1.579930 -0.197842  ...  1.663777  0.603633  0.231452
# no      0.368404 -0.497894  1.567452  ... -0.854184  1.676691 -0.461345
# nt      0.253380  0.760322  0.283970  ...  0.112940  0.636776 -0.657319
# my      0.569960  0.949293  1.057859  ...  0.963320  0.036998  1.260493
# np     -0.776506  0.764746  0.394545  ...  1.099562 -1.051470  0.757635
# al      1.345002 -0.816321  0.992483  ... -1.002387 -1.810059 -0.187311
# vw      1.004061 -0.046574 -1.019231  ... -0.307212 -0.495637 -0.793462
#
# [10 rows x 10 columns]

# %% [markdown]
# multi -index and index hiearchy

# %%
outside = ['x','x','x','x','x','y','y','y','y','y']
inside = [1,2,3,1,2,3,1,2,3,1]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
hier_index
# Out:
# MultiIndex([('x', 1),
#             ('x', 2),
#             ('x', 3),
#             ('x', 1),
#             ('x', 2),
#             ('y', 3),
#             ('y', 1),
#             ('y', 2),
#             ('y', 3),
#             ('y', 1)],
#            )

# %%
df = pd.DataFrame(np.random.randn(10,2),index=hier_index,columns=['k','l'])
df
# Out:
#             k         l
# x 1  1.346737  2.695360
#   2 -0.885228  1.584732
#   3 -2.152585  0.743499
#   1  1.047942  1.865123
#   2 -0.337572  0.886760
# y 3 -1.679045  0.981671
#   1  0.563762 -0.587716
#   2  1.098788 -1.622291
#   3 -0.218422 -1.191155
#   1  0.359040  0.897535

# %%
df.loc['y']
# Out:
#           k         l
# 3 -1.679045  0.981671
# 1  0.563762 -0.587716
# 2  1.098788 -1.622291
# 3 -0.218422 -1.191155
# 1  0.359040  0.897535

# %%
df.loc['x'].loc[2]
# Out:
#           k         l
# 2 -0.885228  1.584732
# 2 -0.337572  0.886760

# %%
df.index.names
# Out:
# FrozenList([None, None])

# %%
df.index.names=['Gp','Nm']

# %%
df
# Out:
#               k         l
# Gp Nm
# x  1   1.346737  2.695360
#    2  -0.885228  1.584732
#    3  -2.152585  0.743499
#    1   1.047942  1.865123
#    2  -0.337572  0.886760
# y  3  -1.679045  0.981671
#    1   0.563762 -0.587716
#    2   1.098788 -1.622291
#    3  -0.218422 -1.191155
#    1   0.359040  0.897535

# %%
df.xs('y')
# Out:
#            k         l
# Nm
# 3  -1.679045  0.981671
# 1   0.563762 -0.587716
# 2   1.098788 -1.622291
# 3  -0.218422 -1.191155
# 1   0.359040  0.897535

# %%
df.xs(['y',3])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py:196: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
#               k         l
# Gp Nm
# y  3  -1.679045  0.981671
#    3  -0.218422 -1.191155

# %%
df.xs(1,level='Nm')
# Out:
#            k         l
# Gp
# x   1.346737  2.695360
# x   1.047942  1.865123
# y   0.563762 -0.587716
# y   0.359040  0.897535

# %% [markdown]
# group by

# %%
 data={'Company':['x','x','y','y','z','z'],
       'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
       'Sales':[200,120,340,124,243,350]}

# %%
df=pd.DataFrame(data)
df
# Out:
#   Company   Person  Sales
# 0       x      Sam    200
# 1       x  Charlie    120
# 2       y      Amy    340
# 3       y  Vanessa    124
# 4       z     Carl    243
# 5       z    Sarah    350

# %%
df.groupby('Company')

# %%
by_comp=df.groupby("Company")

# %%
by_comp.mean()
# Out:
#          Sales
# Company
# x        160.0
# y        232.0
# z        296.5

# %%
df.groupby('Company').mean()
# Out:
#          Sales
# Company
# x        160.0
# y        232.0
# z        296.5

# %%
by_comp.std()
# Out:
#               Sales
# Company
# x         56.568542
# y        152.735065
# z         75.660426

# %%
by_comp.min()
# Out:
#           Person  Sales
# Company
# x        Charlie    120
# y            Amy    124
# z           Carl    243

# %%
by_comp.max()
# Out:
#           Person  Sales
# Company
# x            Sam    200
# y        Vanessa    340
# z          Sarah    350

# %%
by_comp.count()
# Out:
#          Person  Sales
# Company
# x             2      2
# y             2      2
# z             2      2

# %%
by_comp.describe()
# Out:
#         Sales
#         count   mean         std    min     25%    50%     75%    max
# Company
# x         2.0  160.0   56.568542  120.0  140.00  160.0  180.00  200.0
# y         2.0  232.0  152.735065  124.0  178.00  232.0  286.00  340.0
# z         2.0  296.5   75.660426  243.0  269.75  296.5  323.25  350.0

# %%
by_comp.describe().transpose()
# Out:
# Company               x           y           z
# Sales count    2.000000    2.000000    2.000000
#       mean   160.000000  232.000000  296.500000
#       std     56.568542  152.735065   75.660426
#       min    120.000000  124.000000  243.000000
#       25%    140.000000  178.000000  269.750000
#       50%    160.000000  232.000000  296.500000
#       75%    180.000000  286.000000  323.250000
#       max    200.000000  340.000000  350.000000

# %%
by_comp.describe().transpose()['y']
# Out:
# Sales  count      2.000000
#        mean     232.000000
#        std      152.735065
#        min      124.000000
#        25%      178.000000
#        50%      232.000000
#        75%      286.000000
#        max      340.000000
# Name: y, dtype: float64

# %% [markdown]
# merging joining and concatenating

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                        'B': ['B4', 'B5', 'B6', 'B7'],
                        'C': ['C4', 'C5', 'C6', 'C7'],
                        'D': ['D4', 'D5', 'D6', 'D7']},
                         index=[4, 5, 6, 7]) 
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                        'B': ['B8', 'B9', 'B10', 'B11'],
                        'C': ['C8', 'C9', 'C10', 'C11'],
                        'D': ['D8', 'D9', 'D10', 'D11']},
                        index=[8, 9, 10, 11])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# concatenation

# %%
pd.concat([df1,df2,df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1,df2,df3],axis=1)
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %%
left = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
   
right = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                          'D': ['D0', 'D1', 'D2', 'D3']})

# %%
left
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
right
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %% [markdown]
# merging

# %%
pd.merge(left,right,how='inner',on='key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
left = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                        'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3']})
    
right = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                               'key2': ['K0', 'K0', 'K0', 'K0'],
                                  'C': ['C0', 'C1', 'C2', 'C3'],
                                  'D': ['D0', 'D1', 'D2', 'D3']})

# %%
pd.merge(left,right,on=['key1','key2'])
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %%
pd.merge(left,right,how='outer',on=['key1','key2'])
# Out:
#   key1 key2    A    B    C    D
# 0   K0   K0   A0   B0   C0   D0
# 1   K0   K1   A1   B1  NaN  NaN
# 2   K1   K0   A2   B2   C1   D1
# 3   K1   K0   A2   B2   C2   D2
# 4   K2   K1   A3   B3  NaN  NaN
# 5   K2   K0  NaN  NaN   C3   D3

# %%
pd.merge(left, right, how='right', on=['key1', 'key2'])
# Out:
#   key1 key2    A    B   C   D
# 0   K0   K0   A0   B0  C0  D0
# 1   K1   K0   A2   B2  C1  D1
# 2   K1   K0   A2   B2  C2  D2
# 3   K2   K0  NaN  NaN  C3  D3

# %%
pd.merge(left, right, how='left', on=['key1', 'key2'])
# Out:
#   key1 key2   A   B    C    D
# 0   K0   K0  A0  B0   C0   D0
# 1   K0   K1  A1  B1  NaN  NaN
# 2   K1   K0  A2  B2   C1   D1
# 3   K1   K0  A2  B2   C2   D2
# 4   K2   K1  A3  B3  NaN  NaN

# %% [markdown]
# joining

# %%
left = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                      index=['K0', 'K1', 'K2']) 

right = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                    'D': ['D0', 'D2', 'D3']},
                      index=['K0', 'K2', 'K3'])

# %%
left.join(right)
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
left.join(right,how='outer')
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %%
df = pd.DataFrame({'A':[1,2,np.nan],
                  'B':[5,np.nan,np.nan],
                  'C':[1,2,3]})
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df.dropna(thresh=2)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2

# %%
df.fillna(value='x')
# Out:
#    A  B  C
# 0  1  5  1
# 1  2  x  2
# 2  x  x  3

# %%
df['A'].fillna(value=df['A'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %% [markdown]
# operations

# %%
df = pd.DataFrame({'col1':[5,6,7,8,],'col2':[77,88,99,44],'col3':['ab','df','gh','yz']})
df.head()
# Out:
#    col1  col2 col3
# 0     5    77   ab
# 1     6    88   df
# 2     7    99   gh
# 3     8    44   yz

# %% [markdown]
# info on unique values

# %%
df['col1'].unique()
# Out:
# array([5, 6, 7, 8])

# %%
df['col1'].nunique()
# Out:
# 4

# %%
df['col2'].value_counts()
# Out:
# 77    1
# 44    1
# 99    1
# 88    1
# Name: col2, dtype: int64

# %%
newdf=df[(df['col1']>2)&(df['col2']==44)] # approves cond ,gives value pos where col2 ==3  over col1&col3
newdf
# Out:
#    col1  col2 col3
# 3     8    44   yz

# %% [markdown]
# applying funtions

# %%
def times2(x):
 return x*5

# %%
df['col1'].apply(times2)
# Out:
# 0    25
# 1    30
# 2    35
# 3    40
# Name: col1, dtype: int64

# %%
df['col3'].apply(len) # gives the length of the data
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# Name: col3, dtype: int64

# %%
df['col2'].sum()
# Out:
# 308

# %%
del df['col2'] # perm deletes a column of wish

# %%
df
# Out:
#    col1 col3
# 0     5   ab
# 1     6   df
# 2     7   gh
# 3     8   yz

# %% [markdown]
# getting column and index names

# %%
df.columns
# Out:
# Index(['col1', 'col3'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df
# Out:
#    col1 col3
# 0     5   ab
# 1     6   df
# 2     7   gh
# 3     8   yz

# %%
df.sort_values(by='col3')
# Out:
#    col1 col3
# 0     5   ab
# 1     6   df
# 2     7   gh
# 3     8   yz

# %%
df.isnull() # checks for null values
# Out:
#     col1   col3
# 0  False  False
# 1  False  False
# 2  False  False
# 3  False  False

# %%
df.dropna() #drops the values
# Out:
#    col1 col3
# 0     5   ab
# 1     6   df
# 2     7   gh
# 3     8   yz

# %%
df = pd.DataFrame({'col1':[1,2,3,np.nan],
                   'col2':[np.nan,555,666,444],
                   'col3':['abc','def','ghi','xyz']})
df.head()
# Out:
#    col1   col2 col3
# 0   1.0    NaN  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi
# 3   NaN  444.0  xyz

# %%
df.fillna('h') # fills the null values with wish
# Out:
#   col1 col2 col3
# 0    1    h  abc
# 1    2  555  def
# 2    3  666  ghi
# 3    h  444  xyz

# %%
data={'A':['foo','foo','foo','bar','bar','bar'],
     'B':['one','one','two','two','one','one'],
       'C':['x','y','x','y','x','y'],
       'D':[1,3,2,5,4,1]}
df=pd.DataFrame(data)
df
# Out:
#      A    B  C  D
# 0  foo  one  x  1
# 1  foo  one  y  3
# 2  foo  two  x  2
# 3  bar  two  y  5
# 4  bar  one  x  4
# 5  bar  one  y  1

# %%
df.pivot_table(values='D',index=['A','B'],columns=['C'])
# Out:
# C          x    y
# A   B
# bar one  4.0  1.0
#     two  NaN  5.0
# foo one  1.0  3.0
#     two  2.0  NaN

# %% [markdown]
# series

# %%
labels = ['a','b','c']
my_list = [10,20,30]
arr = np.array([10,20,30])
d = {'a':10,'b':20,'c':30}

# %%
pd.Series(data=labels)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
pd.Series(data=my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(my_list,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# numpy arr

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(arr,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(data=labels)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
pd.Series([sum,print,len])
# Out:
# 0      <built-in function sum>
# 1    <built-in function print>
# 2      <built-in function len>
# dtype: object

# %% [markdown]
# using an index

# %%
ser1 = pd.Series([1,2,3,4],index = ['x','y','v','q'])

# %%
ser1
# Out:
# x    1
# y    2
# v    3
# q    4
# dtype: int64

# %%
ser2 = pd.Series([1,2,5,4],index = ['x','y','v','q'])

# %%
ser2
# Out:
# x    1
# y    2
# v    5
# q    4
# dtype: int64

# %%
ser1['y']
# Out:
# 2

# %%
ser1+ser2
# Out:
# x    2
# y    4
# v    8
# q    8
# dtype: int64
