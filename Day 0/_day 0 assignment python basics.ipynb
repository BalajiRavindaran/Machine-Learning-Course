# %%
5+2 #addition
# Out:
# 7

# %%
2* 8 #multiplication
# Out:
# 16

# %%
5/3 # division
# Out:
# 1.6666666666666667

# %%
7**3 #7 power 3
# Out:
# 343

# %%
3%5 #modulus
# Out:
# 3

# %%
6%3
# Out:
# 0

# %%
(7+6)*(8*4)
# Out:
# 416

# %% [markdown]
# variable assignment

# %%
name_of_var=3

# %%
x=4
y=6
z=9

# %%
u = (x+y)*z

# %%
u
# Out:
# 90

# %% [markdown]
# Strings

# %%
'can use single quotes'
# Out:
# 'can use single quotes'

# %%
"also double quotes"
# Out:
# 'also double quotes'

# %%
"can contain lots of quotes"
# Out:
# 'can contain lots of quotes'

# %% [markdown]
# printing

# %%
x= "this  is hello"

# %%
x
# Out:
# 'this  is hello'

# %%
print(x)
# Out:
# this  is hello

# %%
num = 85
name="balaji"

# %%
print("My number is :{first},and my name is: {second}".format (first=num,second=name))
# Out:
# My number is :85,and my name is: balaji

# %%
print("My number is:{},and my name is :{} ".format(num,name))
# Out:
# My number is:85,and my name is :balaji

# %% [markdown]
# lists

# %%
[5,6,7]
# Out:
# [5, 6, 7]

# %%
["hello",1,[1,2]]
# Out:
# ['hello', 1, [1, 2]]

# %%
my_list = ['a','b','c']

# %%
my_list.append('d')

# %%
my_list
# Out:
# ['a', 'b', 'c', 'd']

# %%
my_list[1]
# Out:
# 'b'

# %%
my_list[3]
# Out:
# 'd'

# %%
my_list[1:]
# Out:
# ['b', 'c', 'd']

# %%
my_list[:2]
# Out:
# ['a', 'b']

# %%
my_list[1]='fresh'

# %%
my_list
# Out:
# ['a', 'fresh', 'c', 'd']

# %% [markdown]
# nest

# %%
nest = [4,5,6,[7,8,['AIM']]]

# %%
nest[3]
# Out:
# [7, 8, ['AIM']]

# %%
nest[3][2]
# Out:
# ['AIM']

# %%
nest[3][2][0]
# Out:
# 'AIM'

# %% [markdown]
# dictionaries

# %%
d={'key0':'item0','key1':'item1'}

# %%
d
# Out:
# {'key0': 'item0', 'key1': 'item1'}

# %%
d['key1']
# Out:
# 'item1'

# %% [markdown]
# booleans

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %% [markdown]
# Tuples

# %%
t=(1,2,3,4)

# %%
t[3]
# Out:
# 4

# %%
t[1]='fresh'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-2c455acd596f> in <module>()
# ----> 1 t[1]='fresh'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# sets

# %%
{2,3,4}
# Out:
# {2, 3, 4}

# %%
{2,3,4,2,3,3,3,2,2,2,4,3}
# Out:
# {2, 3, 4}

# %% [markdown]
# comparison op

# %%
3>4
# Out:
# False

# %%
4>3
# Out:
# True

# %%
4>=4
# Out:
# True

# %%
5==5
# Out:
# True

# %%
"GM"=="GN"
# Out:
# False

# %% [markdown]
# logic op

# %%
(3>4)and (3<4)
# Out:
# False

# %%
(3>4) or (3<4)
# Out:
# True

# %%
(1==1) or (4>5) or (4==5)
# Out:
# True

# %% [markdown]
# condition statements

# %%
if 1<2:
   print("yes!")
# Out:
# yes!

# %%
if 2<3:
    print('first')
else:
    print('last')
# Out:
# first

# %%
if 1>2:
  print("first")
else:
  print("last")
# Out:
# last

# %%
if 2==3:
    print('first')
elif 5==5:
    print('second')
else:
    print('Last')
# Out:
# second

# %% [markdown]
# for loops

# %%
seq = [1,2,3,4,5]

# %%
for item in seq:
    print(item)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for item in seq:
  print("yes!")
# Out:
# yes!
# yes!
# yes!
# yes!
# yes!

# %%
for jelly in seq:
  print(jelly*jelly)
# Out:
# 1
# 4
# 9
# 16
# 25

# %% [markdown]
# while loops

# %%
i=3
while i<=8:
  print ("i value is:{}".format(i))
  i=i+0.5
# Out:
# i value is:3
# i value is:3.5
# i value is:4.0
# i value is:4.5
# i value is:5.0
# i value is:5.5
# i value is:6.0
# i value is:6.5
# i value is:7.0
# i value is:7.5
# i value is:8.0

# %% [markdown]
# range()

# %%
range(8)
# Out:
# range(0, 8)

# %%
for i in range(8):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
list(range(8))
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# list comprehension

# %%
x=[2,3,4,5,6,7]

# %%
out=[]
for item in x:
  out.append(item**3)
  print(out)
# Out:
# [8]
# [8, 27]
# [8, 27, 64]
# [8, 27, 64, 125]
# [8, 27, 64, 125, 216]
# [8, 27, 64, 125, 216, 343]

# %%
[item**3 for item in x]
# Out:
# [8, 27, 64, 125, 216, 343]

# %%
x=("john","charles","mike")
y=("jenny","christy","monica")

a=zip(x,y)
print(tuple(a))
# Out:
# (('john', 'jenny'), ('charles', 'christy'), ('mike', 'monica'))

# %%
players=['x','y','z']
scores=[30,40,50]
for pl,sc in zip(players,scores):
  print ("player:%s    scores:%d"%(pl,sc))
# Out:
# player:x    scores:30
# player:y    scores:40
# player:z    scores:50

# %% [markdown]
# x

# %%
def my_func(para1='default'):
  """
  Docstring goes here
  """
  print(para1)

# %%
my_func
# Out:
# <function __main__.my_func>

# %%
my_func()
# Out:
# default

# %%
my_func("new para")
# Out:
# new para

# %%
my_func(para1="new para")
# Out:
# new para

# %%
def square(x):
  return x**2

# %%
out=square(6)
print(out)
# Out:
# 36

# %% [markdown]
# lambda expression

# %%
def num1(var):
  return var**2

# %%
num1(6)
# Out:
# 36

# %%
lambda var: var**2
# Out:
# <function __main__.<lambda>>

# %% [markdown]
# map and filter

# %%
seq=[30,36,42,48,54]
map(num1,seq)

# %%
list(map(num1,seq))
# Out:
# [900, 1296, 1764, 2304, 2916]

# %%
list(map(lambda var:var**2,seq))
# Out:
# [900, 1296, 1764, 2304, 2916]

# %%
filter(lambda item: item%2==0,seq)

# %%
list(filter(lambda item: item%2==0,seq))
# Out:
# [30, 36, 42, 48, 54]

# %% [markdown]
# methods

# %%
x="hii my name is balaji"

# %%
x.lower()
# Out:
# 'hii my name is balaji'

# %%
x.upper()
# Out:
# 'HII MY NAME IS BALAJI'

# %%
x.split()
# Out:
# ['hii', 'my', 'name', 'is', 'balaji']

# %%
tweet = " go sports!#sports"

# %%
tweet.split("!")
# Out:
# [' go sports', '#sports']

# %%
tweet.split("!")[0]
# Out:
# ' go sports'

# %%
d
# Out:
# {'key0': 'item0', 'key1': 'item1'}

# %%
d.keys()
# Out:
# dict_keys(['key0', 'key1'])

# %%
d.items()
# Out:
# dict_items([('key0', 'item0'), ('key1', 'item1')])

# %%
fst =[ 1,2,3]

# %%
fst.pop()
# Out:
# 3

# %%
fst
# Out:
# [1, 2]

# %%
"x" in [1,2,3]
# Out:
# False

# %%
"x" in ["x","y","z"]
# Out:
# True

# %% [markdown]
# excersice

# %%
7**4 # 7 to the power of 4
# Out:
# 2401

# %%
s="hii there sam!" # split s

# %%
s.split()
# Out:
# ['hii', 'there', 'sam!']

# %%
s.split()[0]
# Out:
# 'hii'

# %%
planet="earth"
dia=12742

# %%
print(" the diameter of {} is {} kilometres" .format(planet,dia))
# Out:
#  the diameter of earth is 12742 kilometres

# %%
lst = [1,2,[3,4],[5,[100,200,['hello']],23,11],1,7] # finding the hello word using indexing

# %%
lst [3][1][2][0]
# Out:
# 'hello'

# %%
d = {'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}

# %%
d
# Out:
# {'k1': [1,
#   2,
#   3,
#   {'tricky': ['oh', 'man', 'inception', {'target': [1, 2, 3, 'hello']}]}]}

# %%
d["k1"][3]["tricky"][3]["target"][3]      # getting hello done
# Out:
# 'hello'

# %% [markdown]
# main difference between tuple and list : tuple's value cannot be varied while list's value can be varied ,tuple can be used to read result which are unreadable while lists cannot be used to read diiferent formats of results

# %%
mail ="user@domain.com" #given mail id is reduced to the required format

# %%
mail.split("@")[1]
# Out:
# 'domain.com'

# %%
findDog='Is there a dog here?'

# %%
findDog.split()
# Out:
# ['Is', 'there', 'a', 'dog', 'here?']

# %%
"dog" in findDog.split()
# Out:
# True

# %%
countDog='This dog runs faster than the other dog dude!' #counting no of repetion words in an string

# %%
subcountDog='dog'

# %%
count=countDog.count(subcountDog)

# %%
print("",count)
# Out:
#  2

# %%
seq = ['soup','dog','salad','cat','great']

# %%
check = 's'

# %%
res = [idx for idx in seq if idx[0].lower() == check.lower()]

# %%
print(str(res))
# Out:
# ['soup', 'salad']

# %%
caught_speeding=x

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-260-e30cc771a7e5> in <module>()
# ----> 1 if x<=60:
#       2   print ("No Ticket")
#
# TypeError: '<=' not supported between instances of 'str' and 'int'
